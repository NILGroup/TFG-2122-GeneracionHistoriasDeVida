# %% [markdown]
# # Transformers and Hugging Face

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Primero, importamos GPT2LMHeadModel para la generatción de texto y GPT2Tokenizer como tokenizer del texto.

# %%
from transformers import GPT2LMHeadModel , GPT2Tokenizer

# %% [markdown]
# A continuación, cargamos el tokenizer y se lo pasamos al modelo.

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2') 


tokenizer('Hello world')
# Out:
# {'input_ids': [15496, 995], 'attention_mask': [1, 1]}

# %%
model = GPT2LMHeadModel.from_pretrained('gpt2' , pad_token_id = tokenizer.eos_token_id)

# %% [markdown]
# Después, para generar el texto, añadimos un primer texto a nuestro modelo y después a partir de él, generamos el texto. Antes de todo tenemos que preprocesar (tokenizar) ese primer texto que pasamos al modelo.
#
#
# 'pt' significa PyTorch Tensors
#
# Con endode pasamos de texto a números y con decode pasamos de números a texto.

# %%
texto = "What is love?"
input_ids = tokenizer.encode(texto,return_tensors = 'pt')

# %%
input_ids
# Out:
# tensor([[2061,  318, 1842,   30]])

# %%
tokenizer.decode(input_ids[0])
# Out:
# 'What is love?'

# %% [markdown]
# Para finalizar, generamos el texto a partir del modelo.

# %%
output = model.generate(input_ids, 
    max_length = 200, 
    num_beams = 5,
    no_repeat_ngram_size  = 2,
    early_stopping = True)

# %%
tokenizer.decode(output[0])
# Out:
# 'What is love?\n\nLove is a word that has been around for a long time. It\'s a way of saying "I love you, but I don\'t know what it means to love someone else." It can mean anything from love for the person you love, to a desire to be with someone who is different from you. Love can also mean a lot of different things to different people. For example, if you want to have sex with a man, you can love him because he is your best friend and you are the best person in the world. If you have a crush on a woman, love her because she is the most beautiful woman you will ever meet. You can even love a girl because you know she will be the one who will give you a good night\'s sleep. But love doesn\'t have to mean sex, it can just mean love. And love is not just about sex; it\'s also about being with people who are different than you and who have different'
